# %% [markdown]
# # smoking_status and bmi = most frequent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn import svm
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
data = pd.read_csv('data/dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
data.bmi.fillna(data.bmi.mode().iloc[0], inplace=True)
data.smoking_status.fillna('never smoked', inplace=True)

# %% [markdown]
# ## correlation matrix for numerical data: Pearson

# %%
categorical_data = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
num_corr = data.drop(categorical_data, axis=1).corr()
num_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_96fac_row0_col0, #T_96fac_row1_col1, #T_96fac_row2_col2, #T_96fac_row3_col3, #T_96fac_row4_col4, #T_96fac_row5_col5, #T_96fac_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_96fac_row0_col1, #T_96fac_row0_col2, #T_96fac_row0_col3, #T_96fac_row0_col4, #T_96fac_row0_col6, #T_96fac_row2_col0, #T_96fac_row6_col0, #T_96fac_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_96fac_row0_col5, #T_96fac_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_96fac_row1_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_96fac_row1_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_96fac_row1_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_96fac_row1_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_96fac_row1_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_96fac_row1_col6, #T_96fac_row4_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_96fac_row2_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_96fac_row2_col3, #T_96fac_row3_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_96fac_row2_col4, #T_96fac_row2_col5, #T_96fac_row4_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_96fac_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_96fac_row3_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_96fac_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_96fac_row3_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_96fac_row3_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_96fac_row4_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_96fac_row4_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_96fac_row4_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_96fac_row4_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_96fac_row5_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_96fac_row5_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_96fac_row5_col2, #T_96fac_row6_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_96fac_row5_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_96fac_row5_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_96fac_row5_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_96fac_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_96fac_row6_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_96fac_row6_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96fac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96fac_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_96fac_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_96fac_level0_col2" class="col_heading level0 col2" >hypertension</th>
#       <th id="T_96fac_level0_col3" class="col_heading level0 col3" >heart_disease</th>
#       <th id="T_96fac_level0_col4" class="col_heading level0 col4" >avg_glucose_level</th>
#       <th id="T_96fac_level0_col5" class="col_heading level0 col5" >bmi</th>
#       <th id="T_96fac_level0_col6" class="col_heading level0 col6" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96fac_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_96fac_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_96fac_row0_col1" class="data row0 col1" >0.012760</td>
#       <td id="T_96fac_row0_col2" class="data row0 col2" >0.006571</td>
#       <td id="T_96fac_row0_col3" class="data row0 col3" >0.009234</td>
#       <td id="T_96fac_row0_col4" class="data row0 col4" >0.024634</td>
#       <td id="T_96fac_row0_col5" class="data row0 col5" >0.021039</td>
#       <td id="T_96fac_row0_col6" class="data row0 col6" >0.002976</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_96fac_row1_col0" class="data row1 col0" >0.012760</td>
#       <td id="T_96fac_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_96fac_row1_col2" class="data row1 col2" >0.272169</td>
#       <td id="T_96fac_row1_col3" class="data row1 col3" >0.250188</td>
#       <td id="T_96fac_row1_col4" class="data row1 col4" >0.237627</td>
#       <td id="T_96fac_row1_col5" class="data row1 col5" >0.350231</td>
#       <td id="T_96fac_row1_col6" class="data row1 col6" >0.156049</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row2" class="row_heading level0 row2" >hypertension</th>
#       <td id="T_96fac_row2_col0" class="data row2 col0" >0.006571</td>
#       <td id="T_96fac_row2_col1" class="data row2 col1" >0.272169</td>
#       <td id="T_96fac_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_96fac_row2_col3" class="data row2 col3" >0.119777</td>
#       <td id="T_96fac_row2_col4" class="data row2 col4" >0.160211</td>
#       <td id="T_96fac_row2_col5" class="data row2 col5" >0.151361</td>
#       <td id="T_96fac_row2_col6" class="data row2 col6" >0.075332</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row3" class="row_heading level0 row3" >heart_disease</th>
#       <td id="T_96fac_row3_col0" class="data row3 col0" >0.009234</td>
#       <td id="T_96fac_row3_col1" class="data row3 col1" >0.250188</td>
#       <td id="T_96fac_row3_col2" class="data row3 col2" >0.119777</td>
#       <td id="T_96fac_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_96fac_row3_col4" class="data row3 col4" >0.146938</td>
#       <td id="T_96fac_row3_col5" class="data row3 col5" >0.051753</td>
#       <td id="T_96fac_row3_col6" class="data row3 col6" >0.113763</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row4" class="row_heading level0 row4" >avg_glucose_level</th>
#       <td id="T_96fac_row4_col0" class="data row4 col0" >0.024634</td>
#       <td id="T_96fac_row4_col1" class="data row4 col1" >0.237627</td>
#       <td id="T_96fac_row4_col2" class="data row4 col2" >0.160211</td>
#       <td id="T_96fac_row4_col3" class="data row4 col3" >0.146938</td>
#       <td id="T_96fac_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_96fac_row4_col5" class="data row4 col5" >0.181899</td>
#       <td id="T_96fac_row4_col6" class="data row4 col6" >0.078917</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row5" class="row_heading level0 row5" >bmi</th>
#       <td id="T_96fac_row5_col0" class="data row5 col0" >0.021039</td>
#       <td id="T_96fac_row5_col1" class="data row5 col1" >0.350231</td>
#       <td id="T_96fac_row5_col2" class="data row5 col2" >0.151361</td>
#       <td id="T_96fac_row5_col3" class="data row5 col3" >0.051753</td>
#       <td id="T_96fac_row5_col4" class="data row5 col4" >0.181899</td>
#       <td id="T_96fac_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_96fac_row5_col6" class="data row5 col6" >0.016073</td>
#     </tr>
#     <tr>
#       <th id="T_96fac_level0_row6" class="row_heading level0 row6" >stroke</th>
#       <td id="T_96fac_row6_col0" class="data row6 col0" >0.002976</td>
#       <td id="T_96fac_row6_col1" class="data row6 col1" >0.156049</td>
#       <td id="T_96fac_row6_col2" class="data row6 col2" >0.075332</td>
#       <td id="T_96fac_row6_col3" class="data row6 col3" >0.113763</td>
#       <td id="T_96fac_row6_col4" class="data row6 col4" >0.078917</td>
#       <td id="T_96fac_row6_col5" class="data row6 col5" >0.016073</td>
#       <td id="T_96fac_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# so we can drop id and bmi since they have very small impact on stroke
dropped_data_1 = data.drop(['id', 'bmi'], axis=1)

# %% [markdown]
# from here we can see there are missing values in smoking_status and bmi

# %% [markdown]
# I choose to check what to do with these missed values. Here my options:
# 1. Drop those people from my training set
# 2. Replace the Nan with the mean of the column
# 3. Replace the Nan with the max of the column
# 4. Replace the Nan with the most frequent value of the column

# %% [markdown]
# ## correlation matrix for categorical data: Cramer's V

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns

def cramerV(label,x):
    confusion_matrix = pd.crosstab(label, x)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r,k = confusion_matrix.shape
    phi2 = chi2/n
    phi2corr = max(0,phi2-((k-1)*(r-1))/(n-1))
    rcorr = r - ((r - 1) ** 2) / ( n - 1 )
    kcorr = k - ((k - 1) ** 2) / ( n - 1 )
    try:
        if min((kcorr - 1),(rcorr - 1)) == 0:
            warnings.warn(
            "Unable to calculate Cramer's V using bias correction. Consider not using bias correction",RuntimeWarning)
            v = 0
            print("If condition Met: ",v)
        else:
            v = np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))
            print("Else condition Met: ",v)
    except:
        print("inside error")
        v = 0
    return v
def plot_cramer(df):
    cramer = pd.DataFrame(index=df.columns,columns=df.columns)
    for column_of_interest in df.columns:
        try:
            temp = {}

            columns = df.columns
            for j in range(0,len(columns)):
                v = cramerV(df[column_of_interest],df[columns[j]])
                cramer.loc[column_of_interest,columns[j]] = v
                if (column_of_interest==columns[j]):
                    pass
                else:
                    temp[columns[j]] = v
            cramer.fillna(value=np.nan,inplace=True)
        except:
            print('Dropping row:',column_of_interest)
            pass
    plt.figure(figsize=(7,7))
    sns.heatmap(cramer,annot=True,fmt='.2f')

    plt.title("Cross Correlation plot on Dataframe with CrammerV Correlation Values")
    plt.show()

# %%
categorical_data1 = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'stroke']
data1 = dropped_data_1.copy()
data1['stroke'] = dropped_data_1['stroke'].replace({0:'No', 1:'Yes'})

plot_cramer(data1[categorical_data1])
# Out:
# Else condition Met:  0.9999999999999999
# Else condition Met:  0.030963530214187737
# Else condition Met:  0.06330708849977167
# Else condition Met:  0.0
# Else condition Met:  0.03756532354689769
# Else condition Met:  0.009317660176099647
# Else condition Met:  0.030963530214187737
# Else condition Met:  0.9999497647278632
# Else condition Met:  0.56834175668848
# Else condition Met:  0.0
# Else condition Met:  0.22214436771523005
# Else condition Met:  0.07157882306692893
# Else condition Met:  0.06330708849977167
# Else condition Met:  0.56834175668848
# Else condition Met:  1.0
# Else condition Met:  0.0
# Else condition Met:  0.19354324487915173
# Else condition Met:  0.07534777542412728
# Else condition Met:  0.0
# Else condition Met:  0.0
# Else condition Met:  0.0
# Else condition Met:  0.9999539156818897
# Else condition Met:  0.006039629345240704
# Else condition Met:  0.0
# Else condition Met:  0.03756532354689769
# Else condition Met:  0.22214436771523005
# Else condition Met:  0.19354324487915173
# Else condition Met:  0.006039629345240704
# Else condition Met:  0.9999999999999999
# Else condition Met:  0.04149138526914493
# Else condition Met:  0.009317660176099649
# Else condition Met:  0.07157882306692893
# Else condition Met:  0.07534777542412728
# Else condition Met:  0.0
# Else condition Met:  0.04149138526914492
# Else condition Met:  0.9993496829991746

# %%
# we can drop Residence and gender
final_data = dropped_data_1.drop(['Residence_type', 'gender'], axis=1)
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                43400 non-null  float64
#  1   hypertension       43400 non-null  int64
#  2   heart_disease      43400 non-null  int64
#  3   ever_married       43400 non-null  object
#  4   work_type          43400 non-null  object
#  5   avg_glucose_level  43400 non-null  float64
#  6   smoking_status     43400 non-null  object
#  7   stroke             43400 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 2.6+ MB

# %%
target = final_data.stroke

replacement_map = {
    'ever_married':{'Yes':1, 'No':0},
}


first_x = final_data.replace(replacement_map)
x = pd.get_dummies(first_x, columns=['work_type', 'smoking_status'])

# %%
features = x.copy()

# %%
normalized = pd.DataFrame(Normalizer().fit_transform(x[['avg_glucose_level', 'age']]), columns=['avg_glucose_level', 'age'])
features.avg_glucose_level = normalized[['avg_glucose_level']]
features.age = normalized[['age']]
features
# Out:
#             age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0      0.031523             0              0             0           0.999503
# 1      0.550488             1              0             1           0.834843
# 2      0.071957             0              0             0           0.997408
# 3      0.711972             0              0             1           0.702208
# 4      0.086480             0              0             0           0.996254
# ...         ...           ...            ...           ...                ...
# 43395  0.168105             0              0             0           0.985769
# 43396  0.253590             0              0             1           0.967312
# 43397  0.665612             1              0             1           0.746298
# 43398  0.374098             0              0             1           0.927389
# 43399  0.718054             0              0             1           0.695987
#
#        stroke  work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# 0           0               False                   False              False
# 1           0               False                   False               True
# 2           0               False                   False               True
# 3           0               False                   False               True
# 4           0               False                    True              False
# ...       ...                 ...                     ...                ...
# 43395       0               False                   False              False
# 43396       0                True                   False              False
# 43397       0               False                   False               True
# 43398       0               False                   False               True
# 43399       0               False                   False               True
#
#        work_type_Self-employed  work_type_children  \
# 0                        False                True
# 1                        False               False
# 2                        False               False
# 3                        False               False
# 4                        False               False
# ...                        ...                 ...
# 43395                    False                True
# 43396                    False               False
# 43397                    False               False
# 43398                    False               False
# 43399                    False               False
#
#        smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               False                         True
# 1                               False                         True
# 2                               False                         True
# 3                                True                        False
# 4                               False                         True
# ...                               ...                          ...
# 43395                           False                         True
# 43396                            True                        False
# 43397                            True                        False
# 43398                           False                         True
# 43399                           False                         True
#
#        smoking_status_smokes
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 43395                  False
# 43396                  False
# 43397                  False
# 43398                  False
# 43399                  False
#
# [43400 rows x 14 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             43400 non-null  float64
#  1   hypertension                    43400 non-null  int64
#  2   heart_disease                   43400 non-null  int64
#  3   ever_married                    43400 non-null  int64
#  4   avg_glucose_level               43400 non-null  float64
#  5   stroke                          43400 non-null  int64
#  6   work_type_Govt_job              43400 non-null  bool
#  7   work_type_Never_worked          43400 non-null  bool
#  8   work_type_Private               43400 non-null  bool
#  9   work_type_Self-employed         43400 non-null  bool
#  10  work_type_children              43400 non-null  bool
#  11  smoking_status_formerly smoked  43400 non-null  bool
#  12  smoking_status_never smoked     43400 non-null  bool
#  13  smoking_status_smokes           43400 non-null  bool
# dtypes: bool(8), float64(2), int64(4)
# memory usage: 2.3 MB

# %%
# x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=0, stratify=target)
# print(f'shape of train dataset is x:{x_train.shape} and y:{y_train.shape}')
# print(f'shape of test dataset is x:{x_test.shape} and y:{y_test.shape}')

# %%
# (y_train.value_counts(normalize=True)*100).plot(kind='bar', color='c')
# plt.xlabel('Stroke')
# plt.ylabel('Percentage')
# plt.title('Percentage of Strokes: Train Data Set')

# %%
# (y_test.value_counts(normalize=True)*100).plot(kind='bar', color='c')
# plt.xlabel('Stroke')
# plt.ylabel('Percentage')
# plt.title('Percentage of Strokes: Test Data Set')

# %% [markdown]
# ## SMOTE

# %%
# x_resampled, y_resampled = SMOTE().fit_resample(x_train, y_train)

# %%
# print(x_resampled.shape)
# print(y_resampled.shape)

# %%
# (y_resampled.value_counts(normalize=True)*100).plot(kind='bar', color='c')
# plt.xlabel('Stroke')
# plt.ylabel('Percentage')
# plt.title('Percentage of Strokes')

# %%
# x_train_set = []
# y_train_set = []
# x_test_set = []
# y_test_set = []
f1_scores_set = []
recall_scores_set = []
precision_scores_set = []
accuracy_scores_set = []
confusion_matrices = []
clf = svm.SVC()
sgkf = StratifiedKFold(n_splits=5, shuffle=False)
for train_index, test_index in sgkf.split(features, target):
    print(f'train is {len(train_index)} and test is {len(test_index)}')
    x_train_cv, x_test_cv = features.loc[train_index], features.loc[test_index]
    y_train_cv, y_test_cv = target.loc[train_index], target.loc[test_index]
    # Smote for train data
    x_resampled, y_resampled = SMOTE().fit_resample(x_train_cv, y_train_cv)
    clf.fit(x_resampled, y_resampled)
    predicted = clf.predict(x_test_cv)
    f1 = f1_score(y_test_cv, predicted)
    pr = precision_score(y_test_cv, predicted)
    re = recall_score(y_test_cv, predicted)
    cm = confusion_matrix(y_test_cv, predicted)
    f1_scores_set.append(f1)
    precision_scores_set.append(pr)
    recall_scores_set.append(re)
    confusion_matrices.append(cm)
# Out:
# train is 34720 and test is 8680
# train is 34720 and test is 8680
# train is 34720 and test is 8680
# train is 34720 and test is 8680
# train is 34720 and test is 8680

# %%
print(f'avg f1 score is {pd.Series(f1_scores_set).mean()}')
print(f'avg precision score is {pd.Series(precision_scores_set).mean()}')
print(f'avg f1 recall is {pd.Series(recall_scores_set).mean()}')
# print(f'avg f1 score is {f1_scores_set.mean()}')
# Out:
# avg f1 score is 1.0
# avg precision score is 1.0
# avg f1 recall is 1.0

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3)

# %%
# x_train_set = []
# y_train_set = []
# x_test_set = []
# y_test_set = []
splitted_f1_scores_set = []
splitted_recall_scores_set = []
splitted_precision_scores_set = []
splitted_accuracy_scores_set = []
splitted_confusion_matrices = []
splitted_clf = svm.SVC()
splitted_sgkf = StratifiedKFold(n_splits=5, shuffle=False)
for train_index, test_index in splitted_sgkf.split(x_train, y_train):
    print(f'train is {len(train_index)} and test is {len(test_index)}')
    splitted_x_train_cv, splitted_x_test_cv = features.loc[train_index], features.loc[test_index]
    splitted_y_train_cv, splitted_y_test_cv = target.loc[train_index], target.loc[test_index]
    # Smote for train data
    splitted_x_resampled, splitted_y_resampled = SMOTE().fit_resample(splitted_x_train_cv, splitted_y_train_cv)
    splitted_clf.fit(splitted_x_resampled, splitted_y_resampled)
    splitted_predicted = splitted_clf.predict(splitted_x_test_cv)
    splitted_f1 = f1_score(splitted_y_test_cv, splitted_predicted)
    splitted_pr = precision_score(splitted_y_test_cv, splitted_predicted)
    splitted_re = recall_score(splitted_y_test_cv, splitted_predicted)
    splitted_cm = confusion_matrix(y_test_cv, predicted)
    splitted_f1_scores_set.append(splitted_f1)
    splitted_precision_scores_set.append(splitted_pr)
    splitted_recall_scores_set.append(splitted_re)
    splitted_confusion_matrices.append(splitted_cm)
# Out:
# train is 24304 and test is 6076
# train is 24304 and test is 6076
# train is 24304 and test is 6076
# train is 24304 and test is 6076
# train is 24304 and test is 6076

# %%
print(f'avg f1 score is {pd.Series(splitted_f1_scores_set).mean()}')
print(f'avg precision score is {pd.Series(splitted_precision_scores_set).mean()}')
print(f'avg f1 recall is {pd.Series(splitted_recall_scores_set).mean()}')
# Out:
# avg f1 score is 1.0
# avg precision score is 1.0
# avg f1 recall is 1.0

# %%
final_pred = splitted_clf.predict(x_test)
con = confusion_matrix(y_test, final_pred)

# %%
sns.heatmap(con, annot=True)
# Out:
# <Axes: >
